# %%
import pandas as pd

# %%
print(pd)
# Out:
# <module 'pandas' from 'C:\\Users\\91907\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
dataset={
   ' car':["Bmw","volvo","zenvo"],
    'passing':[0,2,3]
}

var=pd.DataFrame(dataset)

# %%
print(var)
# Out:
#      car  passing
# 0    Bmw        0
# 1  volvo        2
# 2  zenvo        3

# %%
a=[1,2,3]
print(pd.Series(a))#one dimensional array holding data of any type.
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
a=[1,2,3]
print(pd.Series(a,index=["x","y","z"]))
# Out:
# x    1
# y    2
# z    3
# dtype: int64

# %%
cal={"d1":12,"d2":45,"d3":89}
print(pd.Series(cal))
# Out:
# d1    12
# d2    45
# d3    89
# dtype: int64

# %%
datas={
   " cal":[345,113,567],
   " dur":[35,12,60]
}

a=pd.DataFrame(datas,index=[1,2,3])
print(a)
# Out:
#     cal   dur
# 1   345    35
# 2   113    12
# 3   567    60

# %%
#to locate row
print(a.loc[3]) # depends on index we input
# Out:
#  cal    567
#  dur     60
# Name: 3, dtype: int64

# %%
print(a.loc[[3,2]])#list of indexes
# Out:
#     cal   dur
# 3   567    60
# 2   113    12

# %%
df=pd.read_csv('data.csv')

# %%
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
dj=pd.read_json('data.json')

# %%
print(dj.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.5
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.head(10))
print("__________________")
print(dj.head(10))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0
# __________________
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0
# 5        60    102       127     300.5
# 6        60    110       136     374.0
# 7        45    104       134     253.3
# 8        30    109       133     195.1
# 9        60     98       124     269.0

# %%
# for viewing the last rows of dataframe use head() & tail() for last rows

print(df.tail(5))
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
# None

# %%
print(df.head())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
cf=pd.read_csv('clean.csv')

# %%
new_cf=cf.dropna()
print(new_cf.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
print(new_cf.describe())
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count   29.000000   29.000000   29.000000   29.000000
# mean    70.344828  104.103448  129.275862  305.462069
# std     73.386587    7.784347   13.155381   67.030470
# min     30.000000   92.000000  101.000000  195.100000
# 25%     60.000000  100.000000  120.000000  250.700000
# 50%     60.000000  103.000000  128.000000  300.000000
# 75%     60.000000  108.000000  133.000000  345.300000
# max    450.000000  130.000000  175.000000  479.000000

# %%
x=cf["Calories"].mean()
cf["Calories"].fillna(x,inplace=True)

# %%
print(cf.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
cf.dropna(inplace=True)

# %%
print(cf)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
cf.dropna(inplace=True)
# cf['Date'] = pd.to_datetime(cf['Date'])

print(cf.to_string())
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
# --------------------------------------------------------------------------------------------------

# %%
a=[1,23]
var= pd.Series(a,index=[11,22])
print(var)
# Out:
# 11     1
# 22    23
# dtype: int64

# %%
data=pd.DataFrame({
    'a':[1,3,4],
    'b':[5,6,7]
},index=[1,2,3])

print(data)
# Out:
#    a  b
# 1  1  5
# 2  3  6
# 3  4  7

# %%
print(pd.DataFrame(
[[1,2,3],
[5,6,7],
[9,10,11]],
    index=['A','B','C'],
    columns=['A','B','C']
))
# Out:
#    A   B   C
# A  1   2   3
# B  5   6   7
# C  9  10  11

# %%
a=pd.Series([10, 2, 38, 23, 38, 23, 21])
print(a.mean())
print(a.median())
print(a.mode())
print(a.max())
print(a.min())
print(a.sum())
print(a.count())
print(a.describe())
print(a.quantile([0.75,0.25,0.5]))
# Out:
# 22.142857142857142
# 23.0
# 0    23
# 1    38
# dtype: int64
# 38
# 2
# 155
# 7
# count     7.000000
# mean     22.142857
# std      13.284434
# min       2.000000
# 25%      15.500000
# 50%      23.000000
# 75%      30.500000
# max      38.000000
# dtype: float64
# 0.75    30.5
# 0.25    15.5
# 0.50    23.0
# dtype: float64

# %%
print(a.std())
print(a.var())
# Out:
# 13.284434142114991
# 176.47619047619045

# %%
a.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
